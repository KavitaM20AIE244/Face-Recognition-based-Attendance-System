# %% [markdown]
# <a href="https://colab.research.google.com/github/KavitaM20AIE244/Face-Recognition-based-Attendance-System/blob/main/hog_svm_face_detection/HOG_Face_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
# import gc
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
from skimage import transform
from skimage import data, color, feature
import skimage.data
import cv2
from sklearn.feature_extraction.image import PatchExtractor
from skimage import data, transform
from random import sample

from tqdm import tqdm
import os
from sklearn.svm import NuSVC
from sklearn import svm
from sklearn.model_selection import GridSearchCV
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir data

# %%
# !unzip "/content/drive/MyDrive/HOG_face_detection2/data.zip" -d /content/data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/data/neg/motorbike_0080.jpg
#   inflating: /content/data/neg/car_0303.jpg
#   inflating: /content/data/neg/dog_0670.jpg
#   inflating: /content/data/neg/motorbike_0672.jpg
#   inflating: /content/data/neg/fruit_0055.jpg
#   inflating: /content/data/neg/dog_0205.jpg
#   inflating: /content/data/neg/fruit_0919.jpg
#   inflating: /content/data/neg/motorbike_0617.jpg
#   inflating: /content/data/neg/airplane_0630.jpg
#   inflating: /content/data/neg/flower_0408.jpg
#   inflating: /content/data/neg/fruit_0115.jpg
#   inflating: /content/data/neg/car_0324.jpg
#   inflating: /content/data/neg/car_0155.jpg
#   inflating: /content/data/neg/motorbike_0330.jpg
#   inflating: /content/data/neg/car_0702.jpg
#   inflating: /content/data/neg/motorbike_0213.jpg
#   inflating: /content/data/neg/flower_0805.jpg
#   inflating: /content/data/neg/fruit_0600.jpg
#   inflating: /content/data/neg/motorbike_0643.jpg
# ...

# %%
# import shutil

# shutil.rmtree('/content/pos')
# shutil.rmtree('/content/neg')

# %%
# !pwd
# Out:
# /content

# %%
cd /content
# Out:
# /content

# %%
# !git clone https://github.com/KavitaM20AIE244/Face-Recognition-based-Attendance-System.git
# Out:
# Cloning into 'Face-Recognition-based-Attendance-System'...
# remote: Enumerating objects: 54, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 54 (delta 16), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (54/54), 5.61 MiB | 9.18 MiB/s, done.
# Resolving deltas: 100% (16/16), done.

# %%
cd /content
# Out:
# /content

# %%
# !python /content/Face-Recognition-based-Attendance-System/hog_svm_face_detection/hog_feature_extract.py -p /content/data/pos -n /content/data/neg
# Out:
# Calculate HOG descriptors for the positive images and store them
# Positive features saved in ./ComputerVisionProject_FaceDetection/data/features/pos
# Calculate HOG descriptors for the negative images and store them
# Negative features saved in ./ComputerVisionProject_FaceDetection/data/features/neg
# Done...

# %%
import gc
gc.collect()
# Out:
# 0

# %%
# !python /content/Face-Recognition-based-Attendance-System/hog_svm_face_detection/train_face_detection.py -p /content/ComputerVisionProject_FaceDetection/data/features/pos -n /content/ComputerVisionProject_FaceDetection/data/features/neg
# Out:
# Training SVM ...
# Classifier saved to ./ComputerVisionProject_FaceDetection/models/svm.model

# %%
# !wget https://e1.pxfuel.com/desktop-wallpaper/601/987/desktop-wallpaper-1242x2688-tony-stark-bruce-banner-iphone-xs-max-rdj-tony-stark-android.jpg
# Out:
# --2023-07-25 17:16:19--  https://e1.pxfuel.com/desktop-wallpaper/601/987/desktop-wallpaper-1242x2688-tony-stark-bruce-banner-iphone-xs-max-rdj-tony-stark-android.jpg
# Resolving e1.pxfuel.com (e1.pxfuel.com)... 172.67.213.22, 104.21.67.46, 2606:4700:3037::ac43:d516, ...
# Connecting to e1.pxfuel.com (e1.pxfuel.com)|172.67.213.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 126804 (124K) [image/jpeg]
# Saving to: ‘desktop-wallpaper-1242x2688-tony-stark-bruce-banner-iphone-xs-max-rdj-tony-stark-android.jpg’
#
# desktop-wallpaper-1 100%[===================>] 123.83K   776KB/s    in 0.2s
#
# 2023-07-25 17:16:20 (776 KB/s) - ‘desktop-wallpaper-1242x2688-tony-stark-bruce-banner-iphone-xs-max-rdj-tony-stark-android.jpg’ saved [126804/126804]

# %%
# %run /content/Face-Recognition-based-Attendance-System/hog_svm_face_detection/face_detection.py --image /content/desktop-wallpaper-1242x2688-tony-stark-bruce-banner-iphone-xs-max-rdj-tony-stark-android.jpg
# Out:
# Detection:: Location -> (630, 300)
# Scale ->  0 | Confidence Score [0.52085561]
#
# Detection:: Location -> (200, 190)
# Scale ->  2 | Confidence Score [0.75848555]
#
# Detection:: Location -> (300, 110)
# Scale ->  3 | Confidence Score [0.53196713]
#
# Detection:: Location -> (310, 110)
# Scale ->  3 | Confidence Score [1.21927829]
#
# Detection:: Location -> (320, 110)
# Scale ->  3 | Confidence Score [0.59810714]
#
# Detection:: Location -> (300, 120)
# Scale ->  3 | Confidence Score [0.52119378]
#
# Detection:: Location -> (150, 140)
# Scale ->  3 | Confidence Score [1.17084483]
#
# Detection:: Location -> (150, 150)
# Scale ->  3 | Confidence Score [1.52934014]
#
# Detection:: Location -> (0, 470)
# Scale ->  3 | Confidence Score [0.60257092]
#
# Detection:: Location -> (240, 70)
# Scale ->  4 | Confidence Score [0.73509151]
#
# Detection:: Location -> (230, 80)
# Scale ->  4 | Confidence Score [0.58329353]
#
# Detection:: Location -> (240, 80)
# ...
